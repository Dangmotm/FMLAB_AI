# %%
import warnings
warnings.filterwarnings('ignore')
import os
import numpy as np
import matplotlib.pyplot as plt
import cv2
from keras.datasets import mnist
import torch
from torch import nn
import torch.nn.functional as F
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

# %load_ext tensorboard
# !rm -rf './graph/dropout/dropout=0.5,relu/'
# Out:
# 'rm' is not recognized as an internal or external command,
# operable program or batch file.

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
print('Training image: ', x_train.shape)
print('Testing image: ', x_test.shape)
print('Training label: ', y_train.shape)
print('Testing label: ', y_test.shape)
# Out:
# Training image:  (60000, 28, 28)
# Testing image:  (10000, 28, 28)
# Training label:  (60000,)
# Testing label:  (10000,)

# %%
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255.
x_test /= 255.

# %%
class SimpleModel(nn.Module):
    def __init__(self, dropout_rate):
        super(SimpleModel, self).__init__()
        self.dense_1 = nn.Linear(28*28, 128)
        self.dropout = nn.Dropout(dropout_rate)
        self.dense_2 = nn.Linear(128, 10)
        self.relu = nn.ReLU()
        
    def forward(self, x):
        x = x.view(x.size(0), -1)
        x = self.dense_1(x)
        x = self.relu(x)
        x = self.dropout(x)
        output = F.log_softmax(self.dense_2(x))
        return output

# %%
simple_model = SimpleModel(dropout_rate = 0.5).cuda()

for param in simple_model.parameters():
    if param.requires_grad:
        print('param autograd')
        break
        
input = torch.rand(1, 28, 28).cuda()
output = simple_model(input) 

model_parameters = filter(lambda p: p.requires_grad, simple_model.parameters())
params = sum([np.prod(p.size()) for p in model_parameters])
print('Number of parameter:', params)
# Out:
# param autograd
# Number of parameter: 101770

# %%
from imgaug import augmenters as iaa

# %%
image = cv2.imread('cat.jpg')
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()

# %%
crop_and_pad = iaa.CropAndPad(percent = (-0.25, 0.25))

plt.imshow(cv2.cvtColor(crop_and_pad.augment_image(image), cv2.COLOR_BGR2RGB))
plt.show()

# %%
flip_lr = iaa.Fliplr(1)

plt.imshow(cv2.cvtColor(flip_lr.augment_image(image), cv2.COLOR_BGR2RGB))
plt.show()

# %%
flip_ud = iaa.Flipud(1.0)

plt.imshow(cv2.cvtColor(flip_ud.augment_image(image), cv2.COLOR_BGR2RGB))
plt.show()

# %%
affine = iaa.Affine(scale = (0.5, 1.5), rotate = (-15, 15), translate_percent = (-0.2, 0.2))

plt.imshow(cv2.cvtColor(affine.augment_image(image), cv2.COLOR_BGR2RGB))
plt.show()

# %%
avg_blur = iaa.AverageBlur(k = (11, 31))

plt.imshow(cv2.cvtColor(avg_blur.augment_image(image), cv2.COLOR_BGR2RGB))
plt.show()

# %%
gauu_blur = iaa.GaussianBlur(sigma = (5.0, 15.0))

plt.imshow(cv2.cvtColor(gauu_blur.augment_image(image), cv2.COLOR_BGR2RGB))
plt.show()

# %%
dropout = iaa.Dropout(p = (0, 0.2))

plt.imshow(cv2.cvtColor(dropout.augment_image(image), cv2.COLOR_BGR2RGB))
plt.show()

# %%
aug = iaa.Sequential([
    iaa.Affine(translate_px = {"x" : (-40, 40)}),
    iaa.AdditiveGaussianNoise(scale = 0.1 * 255)
])

plt.imshow(cv2.cvtColor(aug.augment_image(image), cv2.COLOR_BGR2RGB))
plt.show()

# %%
aug = iaa.SomeOf(1, [
    iaa.Affine(rotate = 45),
    iaa.AdditiveGaussianNoise(scale = 0.2 * 255),
    iaa.Add(50, per_channel = True),
    iaa.Sharpen(alpha = 0.5)
])

plt.imshow(cv2.cvtColor(aug.augment_image(image), cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[101], line 8
#       1 aug = iaa.SomeOf(1, [
#       2     iaa.Affine(rotate = 45),
#       3     iaa.AdditiveGaussianNoise(scale = 0.2 * 255),
#       4     iaa.Add(50, per_channel = True),
#       5     iaa.Sharpen(alpha = 0.5)
#       6 ])
# ----> 8 plt.imshow(cv2.cvtColor(aug.augment_image(image), cv2.COLOR_BGR2RGB))
#       9 plt.show()
#
# File D:\Conda\envs\Dang\Lib\site-packages\imgaug\augmenters\meta.py:771, in Augmenter.augment_image(self, image, hooks)
#     767 assert image.ndim in [2, 3], (
#     768     "Expected image to have shape (height, width, [channels]), "
#     769     "got shape %s." % (image.shape,))
#     770 iabase._warn_on_suspicious_single_image_shape(image)
# --> 771 return self.augment_images([image], hooks=hooks)[0]
#
# File D:\Conda\envs\Dang\Lib\site-packages\imgaug\augmenters\meta.py:822, in Augmenter.augment_images(self, images, parents, hooks)
#     774 """Augment a batch of images.
#     775
#     776 Parameters
#    (...)    819
#     820 """
#     821 iabase._warn_on_suspicious_multi_image_shapes(images)
# --> 822 return self.augment_batch_(
#     823     UnnormalizedBatch(images=images),
#     824     parents=parents,
#     825     hooks=hooks
#     826 ).images_aug
#
# File D:\Conda\envs\Dang\Lib\site-packages\imgaug\augmenters\meta.py:641, in Augmenter.augment_batch_(self, batch, parents, hooks)
#     639 with _maybe_deterministic_ctx(self):
#     640     if not batch_inaug.empty:
# --> 641         batch_inaug = self._augment_batch_(
#     642             batch_inaug,
#     643             random_state=self.random_state,
#     644             parents=parents if parents is not None else [],
#     645             hooks=hooks)
#     647 # revert augmentables being set to None for non-activated augmenters
#     648 for column in set_to_none:
#
# File D:\Conda\envs\Dang\Lib\site-packages\imgaug\augmenters\meta.py:3395, in SomeOf._augment_batch_(self, batch, random_state, parents, hooks)
#    3386 augmenter_order = self._get_augmenter_order(random_state)
#    3388 # create an array of active augmenters per image
#    3389 # e.g.
#    3390 #  [[0, 0, 1],
#    (...)   3393 # would signal, that augmenter 3 is active for the first image,
#    3394 # augmenter 1 and 3 for the 2nd image and augmenter 1 for the 3rd.
# -> 3395 augmenter_active = self._get_augmenter_active(batch.nb_rows,
#    3396                                               random_state)
#    3398 for augmenter_index in augmenter_order:
#    3399     active = augmenter_active[:, augmenter_index].nonzero()[0]
#
# File D:\Conda\envs\Dang\Lib\site-packages\imgaug\augmenters\meta.py:3368, in SomeOf._get_augmenter_active(self, nb_rows, random_state)
#    3366 nn = self._get_n(nb_rows, random_state)
#    3367 nn = [min(n, len(self)) for n in nn]
# -> 3368 augmenter_active = np.zeros((nb_rows, len(self)), dtype=np.bool)
#    3369 for row_idx, n_true in enumerate(nn):
#    3370     if n_true > 0:
#
# File D:\Conda\envs\Dang\Lib\site-packages\numpy\__init__.py:338, in __getattr__(attr)
#     333     warnings.warn(
#     334         f"In the future `np.{attr}` will be defined as the "
#     335         "corresponding NumPy scalar.", FutureWarning, stacklevel=2)
#     337 if attr in __former_attrs__:
# --> 338     raise AttributeError(__former_attrs__[attr])
#     340 if attr == 'testing':
#     341     import numpy.testing as testing
#
# AttributeError: module 'numpy' has no attribute 'bool'.
# `np.bool` was a deprecated alias for the builtin `bool`. To avoid this error in existing code, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
